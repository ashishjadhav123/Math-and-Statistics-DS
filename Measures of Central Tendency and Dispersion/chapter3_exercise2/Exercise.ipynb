# %% [markdown]
# ## Problem Statement
#
# You work for a fitness company and have gathered data on the fitness activities of 50 individuals using fitness trackers. The dataset is stored in an Excel file named "fitness_data.xlsx" and includes the following columns:
#
# - **name:** Name of the person.
# - **steps_taken:** The number of steps taken by individuals.
# - **calories_burned:** The estimated calories burned by individuals.
# - **sleep_duration(hours):** The number of hours of sleep individuals got on that day.
# - **water_intake(ounces):** The amount of water individuals consumed.

# %% [markdown]
# **Import Necessary Libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Task1
#
# 1. Import the data from the "fitness_data.xlsx" Excel file.
# 2. Display the first few rows of the dataset to get an overview.
# 3. Calculate and display basic statistics (mean, median, min, max) for each column.

# %%
df_input = pd.read_excel('fitness_data.xlsx')
df_input.head()
df_input
# Out:
#          name  steps_taken  calories_burned  sleep_duration(hours)  \
# 0      Akshay        10500             4500                    7.5
# 1       Priya         9800             4200                    7.2
# 2         Raj        11500             4800                    7.0
# 3       Emily        12000             5000                    7.8
# 4       Rohit         8900             4000                    7.0
# 5      Sophie        10600             4600                    8.0
# 6      Sanjay         9500             4100                    6.5
# 7        Emma        10200             4400                    7.2
# 8       Arjun        11200             4800                    7.3
# 9       Lucas         8000             3700                    6.8
# 10      Siraj        10700             4600                    7.5
# 11       Liam        11500             4900                    8.0
# 12      Meera         9400             4100                    6.5
# 13     Olivia         9900             4300                    7.0
# 14      Vivan        11200             4700                    7.0
# 15        Mia         9800             4200                    7.5
# 16      Kabir        10300             4500                    7.8
# 17        Ava        10500             4400                    7.2
# 18      Rohan         9000             3900                    6.8
# 19        Leo        10000             4300                    7.0
# 20       Aria        10800             4600                    7.5
# 21      Elena        11700             4900                   18.0
# 22       Zara         9300             4000                    6.5
# 23       Mila         9700             4200                    7.2
# 24     Vihaan        11000             4700                    7.3
# 25     Oliver         8200             3800                    6.8
# 26       Kavi        10900             4600                    7.5
# 27      Ethan        11600             4800                    8.0
# 28  Chandresh         9400             4000                    6.5
# 29    Sravani        10200             4400                    7.0
# 30  Siddharth        11300             4700                    4.0
# 31     Harper         9800             4200                    7.5
# 32      Anika        10400             4500                    7.8
# 33       Owen        10500             4400                    7.2
# 34      Aarav         8900             3900                    6.8
# 35     Violet        10000             4300                    7.0
# 36       Kian        10600             4600                    7.5
# 37      Aisha        11400             4900                    8.0
# 38       Neha         9200             4000                    6.5
# 39       Luke         9600             4200                    7.2
# 40        Das        11000             4700                    7.3
# 41     Amelia         8100             3800                    6.8
# 42      Sarah        10800             4600                    7.5
# 43      Ahmed        11500             4900                    8.0
# 44   Akanksha         9300             4000                    6.5
# 45    William         9900             4300                    7.0
# 46      Aryan        11200             4700                    7.0
# 47     Naveen         9800             4200                    7.5
# 48       Noah        10200             4500                    7.8
# 49      Kiran        15000             5500                    8.0
#
#     water_intake(ounces)
# 0                     80
# 1                     75
# 2                     90
# 3                     85
# 4                     70
# 5                    100
# 6                     95
# 7                     80
# 8                     75
# 9                     60
# 10                    70
# 11                   100
# 12                    95
# 13                    90
# 14                    75
# 15                    70
# 16                    80
# 17                    75
# 18                    60
# 19                    65
# 20                    80
# 21                   100
# 22                    95
# 23                    90
# 24                    75
# 25                    60
# 26                    70
# 27                   100
# 28                    95
# 29                    90
# 30                    75
# 31                    70
# 32                    80
# 33                    75
# 34                    60
# 35                    65
# 36                    80
# 37                   100
# 38                    95
# 39                    90
# 40                    75
# 41                    60
# 42                    70
# 43                   100
# 44                    95
# 45                    90
# 46                    75
# 47                    70
# 48                    80
# 49                    30

# %%
df_input.describe()
# Out:
#         steps_taken  calories_burned  sleep_duration(hours)  \
# count     50.000000        50.000000              50.000000
# mean   10316.000000      4418.000000               7.396000
# std     1177.052701       370.708092               1.660951
# min     8000.000000      3700.000000               4.000000
# 25%     9625.000000      4200.000000               7.000000
# 50%    10250.000000      4400.000000               7.200000
# 75%    11000.000000      4700.000000               7.500000
# max    15000.000000      5500.000000              18.000000
#
#        water_intake(ounces)
# count             50.000000
# mean              79.600000
# std               14.457538
# min               30.000000
# 25%               70.000000
# 50%               80.000000
# 75%               90.000000
# max              100.000000

# %% [markdown]
# ## Task2:  Range and IQR
#
# 1. Calculate the range of "steps_taken".
# 2. Calculate the range of "calories_burned".
# 3. Calculate the Interquartile Range (IQR) for "sleep_duration(hours)".
# 4. Calculate the IQR for "water_intake(ounces)".

# %%
# Calculate the range of "steps_taken" for the entire week
min_step = df_input['steps_taken'].min()
max_step = df_input['steps_taken'].max()
print(f"Range of steps taken: {max_step - min_step}")

# Calculate the range of "calories_burned" for the entire week
min_calories = df_input['calories_burned'].min()
max_calories = df_input['calories_burned'].max()
print(f"Range of calories burned: {max_calories - min_calories}")

# Calculate the Interquartile Range (IQR) for "sleep_duration(hours)"
q1_sleep = df_input['sleep_duration(hours)'].quantile(0.25).round(2)
q3_sleep = df_input['sleep_duration(hours)'].quantile(0.78).round(2)
iqr_sleep = q3_sleep - q1_sleep
print(f"IQR of sleep duration: {iqr_sleep}")

# Calculate the IQR for "water_intake(ounces)"
q1_water = df_input['water_intake(ounces)'].quantile(0.25).round(2)
q3_water = df_input['water_intake(ounces)'].quantile(0.75).round(2)
iqr_water = q3_water - q1_water
print(f"IQR of water intake: {iqr_water}")

# Print the results
# Out:
# Range of steps taken: 7000
# Range of calories burned: 1800
# IQR of sleep duration: 0.5700000000000003
# IQR of water intake: 20.0

# %% [markdown]
# ## Task3: Box Plot for Steps Taken
#
# - Create a box plot for the "steps_taken" column to visualize the distribution of daily steps taken by individuals. Interpret the box plot and identify any outliers.

# %%
# Set the figure size
plt.figure(figsize=(10, 6))

# Create a box plot for "Steps Taken"
plt.boxplot(df_input['steps_taken'], vert=True, patch_artist=True)

# Set the title and labels
plt.title('Box Plot of Steps Taken')
plt.xlabel('Steps Taken')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Ensure proper layout and display the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Observations
#
# - Most individuals appear to have a median daily step count around 10,000 as indicated by the orange line within the box.
# - The presence of an outlier at 15,000 indicates that there is at least one individual who took an exceptionally high number of steps. This could be due to various reasons, such as an unusually active day or a measurement error.

# %% [markdown]
# ## Task4:
#
# - Use the IQR method to identify and label outliers in the "sleep_duration(hours)" column.

# %%
#defininig the function

# %%
#get the lower and upper limits
lower_limit = q1_sleep - 1.5 * iqr_sleep
upper_limit = q3_sleep + 1.5 * iqr_sleep

# %%
# Identify and label outliers
outliers = df_input.loc[(df_input['sleep_duration(hours)'] < lower_limit) | 
             (df_input['sleep_duration(hours)'] > upper_limit)]


# Display the outliers
print("Outliers in sleep duration:")
outliers
# Out:
# Outliers in sleep duration:
#          name  steps_taken  calories_burned  sleep_duration(hours)  \
# 21      Elena        11700             4900                   18.0
# 30  Siddharth        11300             4700                    4.0
#
#     water_intake(ounces)
# 21                   100
# 30                    75
